# %%
import numpy as np
import matplotlib.pyplot as plt
from seaborn import kdeplot
from scipy.optimize import curve_fit

# %%
r=1
l=3
dr=.1
dl=.1
V=np.pi*r**2*l
print(f"V={V:.2f} cm^3")
# Out:
# V=9.42 cm^3

# %%
dV = V*(np.sqrt((2*dr/r)**2 + (dl/l)**2))
print(f"V={V:.2f} +/- {dV:.2f} cm^3")
# Out:
# V=9.42 +/- 1.91 cm^3

# %%
rm = np.random.normal(size=10000)*dr+r
lm = np.random.normal(size=10000)*dl+l
Vm = np.pi*rm**2*lm
Vm.std()
# Out:
# 1.9165484813744555

# %%
kdeplot(Vm)
# Out:
# <Axes: ylabel='Density'>
